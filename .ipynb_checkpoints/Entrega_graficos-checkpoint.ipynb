# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### Dataset de clientes de banca - Matplotlib

# %% [markdown]
# Variables Potenciales para clientes de banca: poder saber cual es la necesidad de los productos financieros para un mercado especifico e inclusive segmentar el grupo objetivo para llegar con marketing al mismo

# %%
DATA_PATH = 'BankChurners.csv'

# %%
data = pd.read_csv(DATA_PATH)

# %%
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1,1, figsize=(20,10))
plt.yticks(range(0, 15000, 200))
data['Card_Category'].value_counts().plot(kind="bar")
ax.set_ylabel("cantidad de clientes ")
ax.set_xlabel("Tipo de tarjeta de crédito")
# Out:
# Text(0.5, 0, 'Tipo de tarjeta de crédito')

# %% [markdown]
# Este gráfico me permito saber cuantos clientes tengo por tipologia de tarjeta de crédito, de esta forma puedo infererir que la tarjeta que mas se adquiere es la BLUE

# %%
fig, ax = plt.subplots(1,1, figsize=(20,10))
plt.scatter(data['Credit_Limit'],data['Total_Trans_Ct'])
plt.xticks(range(0, 36000, 1000))
plt.yticks(range(0, 150, 10))
ax.set_xlabel("Limites de tarjeta de crédito  (en miles de dolares)")
ax.set_ylabel("Total de Transacciones")
# Out:
# Text(0, 0.5, 'Total de Transacciones')

# %% [markdown]
# En este gráfico podemos ver que la mayor parte de transacciones estan entre 30 y 90 transacciones y que en su mayor parte tienden a ser por montos entre los 1000 y 10.000 dolares

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))
ax.hist(data['Customer_Age'], bins = 10)
plt.xticks(range(25, 70, 5))
# Out:
# ([<matplotlib.axis.XTick at 0x1c515933eb0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# En este gráfico vemos consolidado que la mayoria de edades en las que estan nuestros clientes son entre 45 y 50 años

# %% [markdown]
# ### Dataset de clientes de banca - SEABORN

# %%
tableCross1 = pd.crosstab(data['Education_Level'], data['Marital_Status'])

# %%
tableCross1
# Out:
# Marital_Status   Divorced  Married  Single  Unknown
# Education_Level
# College                86      467     386       74
# Doctorate              36      205     182       28
# Graduate              225     1479    1197      227
# High School           128      949     782      154
# Post-Graduate          41      243     189       43
# Uneducated            136      656     586      109
# Unknown                96      688     621      114

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))
sns.lineplot(data=tableCross1)
ax.tick_params(axis='x', rotation=60)

# %% [markdown]
# Een el grafico superior vemos que predomina el cliente que es graduado y a la vez tiene un matrimonio por lo que puede este ultimo ser un influenciador para el incremento de la compra y utilizacióon de las tarjetas de crédito

# %%
sns.boxplot(x=tableCross1["Married"])
# Out:
# <AxesSubplot:xlabel='Married'>

# %% [markdown]
# Vemos la diferencia de personas que estan casadas con respecto a la cantidad de clientes que aplican en otros aspectos a las cuentas de tarjetas de crédito.

# %%
tableCross2 = pd.crosstab(data['Customer_Age'], data['Card_Category'])

# %%
tableCross2.head()
# Out:
# Card_Category  Blue  Gold  Platinum  Silver
# Customer_Age
# 26               76     0         0       2
# 27               30     0         0       2
# 28               26     0         0       3
# 29               52     1         0       3
# 30               68     0         0       2

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))

sns.scatterplot(data=tableCross2, x='Silver', y='Customer_Age')
# Out:
# <AxesSubplot:xlabel='Silver', ylabel='Customer_Age'>

# %% [markdown]
# El uso de la tarjeta Silver promedia más con respecto a edades mucho mas altas teniendo en cuenta que es una tarjeta mucho más dificil de conseguir ya que se necesitan mas requisitos para la misma.
